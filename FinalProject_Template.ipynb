# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ContextLab/final-project-llm-course/blob/main/FinalProject_Template.ipynb)

# %% [markdown]
# # Final Project: [Your Project Title]
#
# **PSYC 51.17: Models of Language and Communication**
#
# **Team Members:** [List your team members here]
#
# **Due Date: March 9, 2026 at 11:59 PM EST**
#
# ---
#
# ## Abstract
#
# *Provide a brief summary of your project (2-3 sentences).*
#
# ---

# %% [markdown]
# ## Table of Contents
#
# 1. [Introduction](#1-introduction)
# 2. [Setup and Installation](#2-setup-and-installation)
# 3. [Data](#3-data)
# 4. [Approach](#4-approach)
# 5. [Implementation](#5-implementation)
# 6. [Results](#6-results)
# 7. [Discussion](#7-discussion)
# 8. [Conclusion](#8-conclusion)
# 9. [References](#9-references)

# %% [markdown]
# ## 1. Introduction
#
# ### Motivation
#
# *What problem are you solving? Why does it matter?*
#
# TODO: Your motivation here...
#
# ### Research Questions
#
# *What specific questions will you investigate?*
#
# TODO: Your research questions here...
#
# ### Contributions
#
# *What are the main contributions of your project?*
#
# TODO: Your contributions here...

# %% [markdown]
# ## 2. Setup and Installation

# %%
# Install required packages
# Add all packages your project needs
# !pip install -q transformers torch
# !pip install -q datasets
# !pip install -q matplotlib seaborn plotly
# Add more as needed...

# %%
# Core imports
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
import random
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

# Check GPU availability
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")

# %% [markdown]
# ## 3. Data
#
# ### Dataset Description
#
# *Describe the dataset(s) you are using.*
#
# TODO: Your description here...

# %%
# Load your data
# TODO: Implement data loading
# Make sure data can be automatically downloaded or is publicly accessible

# %%
# Explore and visualize your data
# TODO: Add exploratory data analysis

# %% [markdown]
# ## 4. Approach
#
# ### Methods Overview
#
# *Describe your technical approach, models, and methodology.*
#
# TODO: Your approach description here...
#
# ### Design Decisions
#
# *Explain key design decisions and justify them.*
#
# TODO: Your design decisions here...

# %% [markdown]
# ## 5. Implementation
#
# *This is the main section where you implement your project.*

# %%
# Component 1: [Describe what this component does]
# TODO: Your implementation here

# %%
# Component 2: [Describe what this component does]
# TODO: Your implementation here

# %%
# Component 3: [Describe what this component does]
# TODO: Your implementation here

# %%
# Component 4: [Describe what this component does]
# TODO: Your implementation here

# %% [markdown]
# ## 6. Results
#
# ### Quantitative Results
#
# *Present your quantitative findings with tables and figures.*

# %%
# Run experiments and collect results
# TODO: Your experiments here

# %%
# Create visualizations
# TODO: Your visualizations here

# %% [markdown]
# ### Qualitative Results
#
# *Present qualitative examples and analysis.*
#
# TODO: Your qualitative analysis here...

# %%
# Example outputs/demonstrations
# TODO: Show examples of your system in action

# %% [markdown]
# ## 7. Discussion
#
# ### Interpretation of Results
#
# *What do your results mean? What did you learn?*
#
# TODO: Your interpretation here...
#
# ### Limitations
#
# *What are the limitations of your approach?*
#
# TODO: Your limitations here...
#
# ### Future Work
#
# *What would you do with more time/resources?*
#
# TODO: Your future work here...

# %% [markdown]
# ## 8. Conclusion
#
# *Summarize your project and its contributions.*
#
# TODO: Your conclusion here...

# %% [markdown]
# ## 9. References
#
# *List all references used in your project.*
#
# TODO: Your references here...

# %% [markdown]
# ---
#
# ## Appendix
#
# ### Team Contributions
#
# *Describe each team member's contribution.*
#
# | Team Member | Contributions |
# |-------------|---------------|
# | [Name 1] | [Description] |
# | [Name 2] | [Description] |
# | [Name 3] | [Description] |
#
# ### GenAI Usage
#
# *Document how you used GenAI tools (ChatGPT, Claude, Copilot, etc.).*
#
# TODO: Document your GenAI usage here...
